# %%
import joblib
from pathlib import Path

# Load preprocessor
preproc_path = Path("dataset/processed/preprocessor.joblib")
preproc = joblib.load(preproc_path)

# Print numbered features
print("Numbered feature list:\n")
for idx, name in enumerate(preproc.feature_names_in_):
    print(f"f_{idx} → {name}")
# Out:
# Numbered feature list:
#
# f_0 → originp
# f_1 → responp
# f_2 → flow_duration
# f_3 → fwd_pkts_tot
# f_4 → bwd_pkts_tot
# f_5 → fwd_data_pkts_tot
# f_6 → bwd_data_pkts_tot
# f_7 → fwd_pkts_per_sec
# f_8 → bwd_pkts_per_sec
# f_9 → flow_pkts_per_sec
# f_10 → down_up_ratio
# f_11 → fwd_header_size_tot
# f_12 → fwd_header_size_min
# f_13 → fwd_header_size_max
# f_14 → bwd_header_size_tot
# f_15 → bwd_header_size_min
# f_16 → bwd_header_size_max
# f_17 → flow_FIN_flag_count
# f_18 → flow_SYN_flag_count
# f_19 → flow_RST_flag_count
# f_20 → fwd_PSH_flag_count
# f_21 → bwd_PSH_flag_count
# f_22 → flow_ACK_flag_count
# f_23 → fwd_URG_flag_count
# f_24 → bwd_URG_flag_count
# f_25 → flow_CWR_flag_count
# f_26 → flow_ECE_flag_count
# f_27 → fwd_pkts_payload.min
# f_28 → fwd_pkts_payload.max
# f_29 → fwd_pkts_payload.tot
# f_30 → fwd_pkts_payload.avg
# f_31 → fwd_pkts_payload.std
# f_32 → bwd_pkts_payload.min
# f_33 → bwd_pkts_payload.max
# f_34 → bwd_pkts_payload.tot
# ...
